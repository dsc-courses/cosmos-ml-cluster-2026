# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (4, 3)

# %% [markdown]
# # License Plate Data
#
# In Oakland (and in many other cities), police cars have automated license plate
# readers that periodically read the license plates they see nearby as they
# patrol the city. This dataset of license plate readings was taken from the
# Oakland public records.
#
# We're going to explore this data. You should work in pairs, since tackling these
# tasks will require making your own judgement calls about how to analyze the
# data. You should use LLMs, including ChatGPT / Claude / Gemini for this
# challenge, since it's likely more advanced than your current knowledge.

# %%
df = pd.read_csv('https://github.com/DS-100/textbook/raw/refs/heads/master/content/datasets/license-plates.csv.gz')
df.columns = ['plate', 'time', 'location']
df
# Out:
#            plate                    time  \
# 0        1275226  01/19/2011 02:06:00 AM
# 1         27529C  01/19/2011 02:06:00 AM
# 2        1158423  01/19/2011 02:06:00 AM
# 3        1273718  01/19/2011 02:06:00 AM
# 4        1077682  01/19/2011 02:06:00 AM
# ...          ...                     ...
# 2742096  4HMN225  12/19/2013 08:28:00 PM
# 2742097  5CQR629  12/19/2013 08:28:00 PM
# 2742098  5X10319  12/19/2013 08:28:00 PM
# 2742099  7D56240  12/19/2013 08:28:00 PM
# 2742100  6JNM127  12/19/2013 08:28:00 PM
#
#                                           location
# 0        (37.798304999999999, -122.27574799999999)
# 1        (37.798304999999999, -122.27574799999999)
# 2        (37.798304999999999, -122.27574799999999)
# 3        (37.798304999999999, -122.27574799999999)
# 4        (37.798304999999999, -122.27574799999999)
# ...                                            ...
# 2742096                   (37.804198, -122.285053)
# 2742097                   (37.804171, -122.284955)
# ...

# %% [markdown]
# ## Task 1: Explore and clean the data
#
# Let's prepare this data for future analysis. Take a look at the dataframe
# and come up with a list of data cleaning steps that you think will be necessary.

# %% [markdown]
# List out your steps here:
#
# 1. [fill me in]
# 1. [fill me in]
# 1. [fill me in]

# %% [markdown]
# Now, write `pandas` code to clean up `df`. You can use your favorite LLM to
# write the code for you, and ask an instructor if you want an explanation for
# what the code does.

# %%
# your code here.

# %% [markdown]
# After you're done, you should be able to answer the following questions:
#
# 1. What are the dates spanned by this data?
# 2. How many license plate readings happen per day on average?
# 3. Are there more readings on weekdays? Or weekends?
# 4. How many vehicles appear in this dataset more than 10 times? 20 times?

# %% [markdown]
# ## Task 2: Visualizing Jean Quan's locations
#
# [jean]: https://en.wikipedia.org/wiki/Jean_Quan
# [news]: https://www.sfgate.com/bayarea/matier-ross/article/Jean-Quan-Oakland-s-new-mayor-gets-car-booted-3164530.php
#
# [Jean Quan][jean] was the mayor of Oakland from 2011 to 2015. At the time, her
# license plate number was 6FCH845, at least according to this [news
# article][news] that includes a picture of her car.
#
# Find a way to visualize where her car was spotted in Oakland.
#
# Hint: you might want to try using the `folium` Python package to make a map.

# %% [markdown]
# What do you notice?

# %% [markdown]
# ## Task 3: Visualizing Other People
#
# Visualize the locations for this license plate: 5AJG153 .
#
# After that, visualize this one: 6UZA652 .
#
# What can you infer about these people from where their license plates were
# spotted?
#
# Hint: Try color-coding the locations. For example, you might color-code weekend
# sightings in blue, while keeping weekdays in green. Or, you might color-code
# nighttime sightings in red.

# %% [markdown]
# If you did this right, you might be feeling a bit creeped out! Talk with your
# partner or an instructor about the ethical implications of collecting this sort
# of data. For example, what other organizations might have access to this kind of
# data?
