# %% [markdown]
# <a href="https://colab.research.google.com/github/dsc-courses/cosmos-ml-cluster-2026/blob/main/labs/lab09/lab09_spam_filter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Spam Filter Lab Using Actual Spam Dataset
#
# Dataset: https://drive.google.com/file/d/1HEHhG0WQXC8evXouLJHavr9qDiCJtWgZ/view?usp=sharing

# %%
import pandas as pd
import numpy as np

# %%
! gdown 1HEHhG0WQXC8evXouLJHavr9qDiCJtWgZ

# %%
df = pd.read_csv('spam.csv')
df.head()

# %% [markdown]
# ## Create an additional column named "Spam" in the dataframe that has the numerical values of 0 and 1 for "ham" and "spam" respectively.

# %% [markdown]
# ## Train test split

# %% [markdown]
# ## Clean Up each text, using spaCy

# %% [markdown]
# ## Create bag of words representation using CountVectorizer

# %% [markdown]
# ## Train the following models for classifying spam vs ham emails
# ### You should train at least THREE of the following classification models:
# 1. Naive Bayes
# 2. Logistic Regression
# 3. Decision Trees
# 4. k-Nearest Neighbors
#
# You can also train any other classifers that you may be aware of.

# %%
#model 1

model_nb =

# %%
#model 2

model_logreg =

# %%
#model 3

model_dt =

# %%
#model 4 (optional)

model_knn =

# %% [markdown]
# ## Vectorize the test data set

# %% [markdown]
# ## Compute and Display Evaluation Reports for all the classifers you trained (at least three)

# %%
#model 1 classification report

# %%
#model 2 classification report

# %%
#model 3 classification report

# %%
#model 4 classification report (optional)

# %% [markdown]
# ### How do your models classify the following two emails?

# %%
emails = [
    'Hey Pamela, how are you doing?',
    'Click this to get money and cheap loans now'
]

emails_count = cv.transform(emails)
print(model_nb.predict(emails_count))
print(model_dt.predict(emails_count))
print(model_knn.predict(emails_count))
print(model_logreg.predict(emails_count))

# %% [markdown]
# ##1. Which of your models performed the best and which performed the worst? What are your thoughts on the reasoning behind why some perform well and others not as well with spam classification?

# %% [markdown]
# ##2. This time train the model after preprocessing the data using SpaCy. Does it improve prediction performance?
