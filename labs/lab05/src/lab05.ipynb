# %% [raw]
# # ASSIGNMENT CONFIG
# config_file: ../../otter-config.yml
# files:
#     - data

# %% [markdown]
# # Lab 5: Nearest Neighbors
#
# Welcome to Lab 5! In this lab, you will build two classifiers from scratch: a 1-nearest-neighbor classifier and a k-nearest-neighbors classifier. You should complete this entire lab so that all tests pass.
#
# We will use a Spotify dataset to predict whether a song is **classical**, **hip-hop**, or **rock**. As in Lecture 7, our two features are `speechiness` and `acousticness`.
#
# **Do not import or use scikit-learn in this lab.** The point is to understand the nearest-neighbor algorithm by writing it yourself.

# %%
in_colab = "google.colab" in str(get_ipython())
if in_colab:
    # !pip install otter-grader==6.1.6

from pathlib import Path
import shutil
import zipfile

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

path = 'labs/lab05/build/student'
if in_colab and not Path('data').exists():
    # !wget -q -O /content/course.zip https://github.com/dsc-courses/cosmos-ml-cluster-2026/archive/refs/heads/main.zip
    with zipfile.ZipFile('/content/course.zip') as course_zip:
        archive_prefix = f'cosmos-ml-cluster-2026-main/{path}/'
        members = [name for name in course_zip.namelist() if name.startswith(archive_prefix)]
        course_zip.extractall('/content/course-assets', members)
    source_path = Path('/content/course-assets') / archive_prefix
    shutil.copytree(source_path / 'data', 'data', dirs_exist_ok=True)
    shutil.copytree(source_path / 'tests', 'tests', dirs_exist_ok=True)

import otter
grader = otter.Notebook()

plt.style.use('seaborn-v0_8-colorblind')
plt.rcParams['figure.figsize'] = (10, 5)

# %% [markdown]
# ## The Spotify data 🎵
#
# Each row in `songs` describes one song. The column `genre` is the label we want to predict. We will use all seven numerical audio features:
#
# - `danceability`
# - `energy`
# - `speechiness`
# - `acousticness`
# - `instrumentalness`
# - `liveness`
# - `valence`
#
# In Lecture 7, we used only `speechiness` and `acousticness` because two features can be shown on a scatter plot, which made the nearest-neighbor idea easier to teach. In a real classification task, you would often want to use all of the relevant information available to you. Here, our classifiers will use all seven audio features.
#
# The cells below make a fixed training set and test set. The training songs are the labeled examples a classifier may use; the test songs are held aside until we evaluate the classifier.

# %%
songs = pd.read_csv('data/spotify-three-genres.csv').rename(columns={'track_genre': 'genre'})
songs.head()
# Out:
#                  track_id                                            artists  \
# 0  0fMditvyHKtvP0Wda7b3Wt             Wolfgang Amadeus Mozart;Danielle Laval
# 1  0JAzwrikHrPWVK02ANRkHl             Wolfgang Amadeus Mozart;Giuseppe Greco
# 2  7FM43USRDOLBicvp6Zvnjk   Wolfgang Amadeus Mozart;I Musici;Pina Carmirelli
# 3  4N9wT4gXdCIVIoyYrGQ5ms  Wolfgang Amadeus Mozart;Wiener Mozart Ensemble...
# 4  58ina5MM56CHWVlIbXiAZT  Antonio Vivaldi;Gidon Kremer;Leslie Pearson;Lo...
#
#                                           track_name  danceability   energy  \
# 0  12 Variations on ‘La belle Françoise’ in E fla...         0.389  0.11300
# 1  Piano Sonata No. 17 in B-Flat Major, K. 570: I...         0.445  0.00884
# 2                   Serenade in G, K.525: 1. Allegro         0.449  0.24700
# 3  Contredanse in E flat, K.607 "Il Trionfo delle...         0.636  0.20300
# 4  Violin Concerto in F Minor, Op. 8, No. 4, RV 2...         0.513  0.28700
#
#    speechiness  acousticness  instrumentalness  liveness  valence      genre
# 0       0.0382         0.991           0.84200    0.1360    0.740  classical
# 1       0.0780         0.995           0.91300    0.0907    0.216  classical
# 2       0.0405         0.866           0.86900    0.2160    0.620  classical
# 3       0.0412         0.964           0.32600    0.1710    0.717  classical
# 4       0.0472         0.976           0.00247    0.0991    0.265  classical

# %% [markdown]
# ## 1. 1-Nearest Neighbor
#
# A **1-nearest-neighbor classifier** predicts the genre of a new song by finding the one labeled training song closest to it and copying that song's genre.

# %% [markdown]
# **Question 1.1.** Store a list containing all seven feature-column names, in the order shown above, in `features`. Store the string `'genre'` in `target`. Then create `feature_songs`, a DataFrame containing only the columns in `features`.

# %% [raw]
# # BEGIN QUESTION
# name: q1_1

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION
features = ['danceability', 'energy', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence']
target = 'genre'
feature_songs = songs[features]
# END SOLUTION
feature_songs.head()
# Out:
#    danceability   energy  speechiness  acousticness  instrumentalness  \
# 0         0.389  0.11300       0.0382         0.991           0.84200
# 1         0.445  0.00884       0.0780         0.995           0.91300
# 2         0.449  0.24700       0.0405         0.866           0.86900
# 3         0.636  0.20300       0.0412         0.964           0.32600
# 4         0.513  0.28700       0.0472         0.976           0.00247
#
#    liveness  valence
# 0    0.1360    0.740
# 1    0.0907    0.216
# 2    0.2160    0.620
# 3    0.1710    0.717
# 4    0.0991    0.265

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
bool(features == ['danceability', 'energy', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence'])
# Out:
# True

# %%
bool(target == 'genre')
# Out:
# True

# %%
bool(isinstance(feature_songs, pd.DataFrame) and feature_songs.columns.tolist() == features and feature_songs.shape[0] == songs.shape[0])
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# Next, run the cell below to create the train and test set you'll use for the remainder of the lab.

# %%
# Create the train/test sets from the feature table.
test_indices = songs.sample(frac=0.2, random_state=42).index
test_songs = songs.loc[test_indices]
training_songs = songs.drop(index=test_indices)
test_features = feature_songs.loc[test_indices]
training_features = feature_songs.drop(index=test_indices)
test_labels = test_songs[target]
training_labels = training_songs[target]

print(f'Training songs: {training_features.shape[0]:,}')
print(f'Test songs: {test_features.shape[0]:,}')
# Out:
# Training songs: 2,239
# Test songs: 560

# %% [markdown]
# **Question 1.2.** Create a Series named `songs_per_genre` that counts the number of training songs in each genre. Its index should contain the genre names and it should be sorted alphabetically by genre.
#
# Then make a scatter plot of `speechiness` (x-axis) and `acousticness` (y-axis) for the training songs. Color the points according to each song's genre.

# %% [raw]
# # BEGIN QUESTION
# name: q1_2

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION
songs_per_genre = training_songs.groupby('genre').size().sort_index()
genre_colors = {'classical': 'tab:blue', 'hip-hop': 'tab:orange', 'rock': 'tab:green'}
training_songs.plot(kind='scatter', x='speechiness', y='acousticness', c=training_songs['genre'].map(genre_colors), alpha=0.5);
songs_per_genre
# END SOLUTION
# Out:
# genre
# classical    753
# hip-hop      738
# rock         748
# dtype: int64

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
bool(isinstance(songs_per_genre, pd.Series))
# Out:
# True

# %%
bool(songs_per_genre.index.tolist() == ['classical', 'hip-hop', 'rock'])
# Out:
# True

# %%
bool(songs_per_genre.sum() == training_songs.shape[0])
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# **Question 1.3.** Define a function called `distance`. It should take two Series, `song_a` and `song_b`, each containing numerical feature values, and return their ordinary straight-line distance using every value in the Series.
#
# With $p$ features, the distance is $\sqrt{(a_1-b_1)^2 + (a_2-b_2)^2 + \cdots + (a_p-b_p)^2}$.
#
# **Do not use a `for`-loop for this question.** Use arithmetic on the two Series instead.

# %% [raw]
# # BEGIN QUESTION
# name: q1_3

# %% [raw]
# # BEGIN SOLUTION

# %%
def distance(song_a, song_b):
    """Return the p-dimensional distance between two numerical Series."""
    # BEGIN SOLUTION
    return np.sqrt(((song_a - song_b) ** 2).sum())
    # END SOLUTION

distance(training_features.iloc[0], training_features.iloc[1])
# Out:
# np.float64(0.5452104507435638)

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
song_a = pd.Series([0.0, 0.0, 0.0])
song_b = pd.Series([3.0, 4.0, 12.0])
bool(np.isclose(distance(song_a, song_b), 13.0))
# Out:
# True

# %%
song_a = pd.Series([1.0, 2.0])
song_b = pd.Series([4.0, 6.0])
bool(np.isclose(distance(song_a, song_b), 5.0))
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# **Question 1.4.** Define `distances_to_song(new_song, labeled_songs)`. Here, `new_song` is a Series of numerical feature values and `labeled_songs` is a DataFrame containing only numerical feature columns. Return a Series containing the distance from every row of `labeled_songs` to `new_song`. The Series must have the same index as `labeled_songs`. Use arithmetic on DataFrames and Series; do not convert the data to NumPy arrays and back.

# %% [raw]
# # BEGIN QUESTION
# name: q1_4

# %% [raw]
# # BEGIN SOLUTION

# %%
def distances_to_song(new_song, labeled_songs):
    """Return the distance from each numerical feature row to new_song."""
    # BEGIN SOLUTION
    squared_differences = (labeled_songs - new_song) ** 2
    return np.sqrt(squared_differences.sum(axis=1))
    # END SOLUTION

distances_to_song(test_features.iloc[0], training_features).head()
# Out:
# 0    1.397302
# 1    1.526585
# 2    1.272223
# 3    1.066816
# 4    1.032815
# dtype: float64

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
small_songs = pd.DataFrame([[0.0, 0.0, 0.0], [3.0, 4.0, 12.0]], columns=['a', 'b', 'c'], index=['first', 'second'])
new_song = pd.Series([0.0, 4.0, 12.0], index=['a', 'b', 'c'])
answer = distances_to_song(new_song, small_songs)
bool(isinstance(answer, pd.Series) and answer.index.tolist() == ['first', 'second'] and np.allclose(answer.to_numpy(), np.array([np.sqrt(160), 3.0])))
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# **Question 1.5.** Define `nearest_song(new_song, labeled_songs)`. It should return the entire numerical feature row of `labeled_songs` that is closest to `new_song`. You may use the function from Question 1.4.
#
# When used on a DataFrame, `.loc` with a single label returns one row as Series by their index label, while `.iloc` selects rows by their integer **position**. For example, `data.loc['song-17']` returns the row whose index label is `'song-17'`, while `data.iloc[0]` returns the first row. The index label returned by `idxmin()` can be used with `.loc`.

# %% [raw]
# # BEGIN QUESTION
# name: q1_5

# %% [raw]
# # BEGIN SOLUTION

# %%
def nearest_song(new_song, labeled_songs):
    """Return the numerical feature row closest to new_song."""
    # BEGIN SOLUTION
    distances = distances_to_song(new_song, labeled_songs)
    return labeled_songs.loc[distances.idxmin()]
    # END SOLUTION

nearest_song(test_features.iloc[0], training_features)
# Out:
# danceability        0.705000
# energy              0.852000
# speechiness         0.252000
# acousticness        0.226000
# instrumentalness    0.000626
# liveness            0.140000
# valence             0.671000
# Name: 1013, dtype: float64

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
small_songs = pd.DataFrame([[0.0, 0.0], [0.9, 0.9], [0.2, 0.2]], columns=['a', 'b'], index=['a', 'b', 'c'])
new_song = pd.Series([0.15, 0.15], index=['a', 'b'])
answer = nearest_song(new_song, small_songs)
bool(isinstance(answer, pd.Series) and answer.name == 'c' and np.allclose(answer.to_numpy(), np.array([0.2, 0.2])))
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# **Question 1.6.** Define `predict_1nn(new_song, labeled_songs, labels)`. `new_song` and `labeled_songs` contain only numerical features, while `labels` is a Series of genres indexed like `labeled_songs`. Return the label of the closest labeled song as a string. Use `nearest_song` rather than repeating its work.

# %% [raw]
# # BEGIN QUESTION
# name: q1_6

# %% [raw]
# # BEGIN SOLUTION

# %%
def predict_1nn(new_song, labeled_songs, labels):
    """Predict a genre using the closest labeled song."""
    # BEGIN SOLUTION
    closest = nearest_song(new_song, labeled_songs)
    return labels.loc[closest.name]
    # END SOLUTION

predict_1nn(test_features.iloc[0], training_features, training_labels)
# Out:
# 'hip-hop'

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
small_songs = pd.DataFrame([[0.02, 0.90], [0.70, 0.02], [0.30, 0.10]], columns=['a', 'b'])
labels = pd.Series(['classical', 'hip-hop', 'rock'])
new_song = pd.Series([0.65, 0.05], index=['a', 'b'])
first_prediction = predict_1nn(new_song, small_songs, labels)
new_song = pd.Series([0.04, 0.80], index=['a', 'b'])
second_prediction = predict_1nn(new_song, small_songs, labels)
bool(first_prediction == 'hip-hop' and second_prediction == 'classical')
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# **Question 1.7.** Use `predict_1nn` to predict every song in `test_features`. Store the predictions in a Series named `one_nn_predictions`, with the same index as `test_features`.

# %% [raw]
# # BEGIN QUESTION
# name: q1_7

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION
one_nn_predictions = test_features.apply(
    lambda song: predict_1nn(song, training_features, training_labels), axis=1
)
# END SOLUTION
one_nn_predictions.head()
# Out:
# 1088      hip-hop
# 772     classical
# 2616         rock
# 1192      hip-hop
# 1651      hip-hop
# dtype: str

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
bool(isinstance(one_nn_predictions, pd.Series))
# Out:
# True

# %%
bool(one_nn_predictions.index.equals(test_features.index))
# Out:
# True

# %%
bool(one_nn_predictions.isin(training_labels.unique()).all())
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# **Question 1.8.** Make a DataFrame named `one_nn_results` with the columns `'genre'`, `'predicted_genre'`, and `'correct'`. It should contain the actual genre, the 1-NN prediction, and whether the prediction was correct for every test song. Then assign the proportion of correct predictions to `one_nn_accuracy`.

# %% [raw]
# # BEGIN QUESTION
# name: q1_8

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION
one_nn_results = pd.DataFrame({
    'genre': test_labels,
    'predicted_genre': one_nn_predictions
})
one_nn_results = one_nn_results.assign(
    correct=one_nn_results['genre'] == one_nn_results['predicted_genre']
)
one_nn_accuracy = one_nn_results['correct'].mean()
# END SOLUTION
one_nn_accuracy
# Out:
# np.float64(0.8553571428571428)

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
bool(isinstance(one_nn_results, pd.DataFrame) and set(one_nn_results.columns) == {'genre', 'predicted_genre', 'correct'})
# Out:
# True

# %%
bool(one_nn_results.shape[0] == test_songs.shape[0] and one_nn_results['correct'].dtype == bool)
# Out:
# True

# %%
bool(np.isclose(one_nn_accuracy, one_nn_results['correct'].mean()))
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# **Question 1.9.** Create `one_nn_mistakes`, a DataFrame containing only the rows of `one_nn_results` where the prediction was incorrect. Then store its number of rows in `one_nn_num_mistakes`.

# %% [raw]
# # BEGIN QUESTION
# name: q1_9

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION
one_nn_mistakes = one_nn_results[~one_nn_results['correct']]
one_nn_num_mistakes = one_nn_mistakes.shape[0]
one_nn_mistakes.head()
# END SOLUTION
# Out:
#         genre predicted_genre  correct
# 2211     rock         hip-hop    False
# 1395  hip-hop            rock    False
# 2598     rock         hip-hop    False
# 1011  hip-hop            rock    False
# 1754  hip-hop       classical    False

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
bool(isinstance(one_nn_mistakes, pd.DataFrame) and (~one_nn_mistakes['correct']).all())
# Out:
# True

# %%
bool(one_nn_num_mistakes == one_nn_mistakes.shape[0])
# Out:
# True

# %%
bool(one_nn_num_mistakes + one_nn_results['correct'].sum() == test_songs.shape[0])
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# ### Listen to some 1-NN mistakes
#
# Run the next cell to inspect a few songs that 1-NN classified incorrectly. The embedded players let you listen to them and compare the actual genre with the prediction.

# %%
from IPython.display import HTML, display

def play_song(track_id, title):
    display(HTML(f'''<p><strong>{title}</strong></p>
    <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/{track_id}?utm_source=generator"
    width="100%" height="152" frameBorder="0" allowfullscreen=""
    allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>'''))

mistaken_songs = test_songs.loc[one_nn_mistakes.index].copy()
mistaken_songs['predicted_genre'] = one_nn_mistakes['predicted_genre']
songs_to_play = mistaken_songs.head(3)

display(songs_to_play[['track_name', 'artists', 'genre', 'predicted_genre']])

for _, song in songs_to_play.iterrows():
    play_song(
        song['track_id'],
        f"{song['track_name']} — actual: {song['genre']}; predicted: {song['predicted_genre']}"
    )
# Out:
#                        track_name           artists    genre predicted_genre
# 2211  It's Not My Time - Acoustic      3 Doors Down     rock         hip-hop
# 1395                       Bewafa        Imran Khan  hip-hop            rock
# 2598          Best Day Of My Life  American Authors     rock         hip-hop
# <p><strong>It's Not My Time - Acoustic — actual: rock; predicted: hip-hop</strong></p>
#     <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/74NANS3BFQRnpz3S0JVg5o?utm_source=generator"
#     width="100%" height="152" frameBorder="0" allowfullscreen=""
#     allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>
# <p><strong>Bewafa — actual: hip-hop; predicted: rock</strong></p>
#     <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/4FcknXDJ8yW2QYUl0cm6uJ?utm_source=generator"
#     width="100%" height="152" frameBorder="0" allowfullscreen=""
#     allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>
# <p><strong>Best Day Of My Life — actual: rock; predicted: hip-hop</strong></p>
#     <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/5Hroj5K7vLpIG4FNCRIjbP?utm_source=generator"
#     width="100%" height="152" frameBorder="0" allowfullscreen=""
#     allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>

# %% [markdown]
# ## 2. k-Nearest Neighbors
#
# A 1-NN classifier lets one training song make the whole decision. A **k-nearest-neighbors (k-NN)** classifier instead finds the $k$ closest training songs and lets them vote. We will use an odd value of $k$ most of the time, but ties can still happen when there are three genres.

# %% [markdown]
# **Question 2.1.** Define `k_nearest_songs(new_song, labeled_songs, k)`. It should return the `k` closest rows of `labeled_songs`, sorted from smallest to largest distance. The returned DataFrame must include a new column called `'distance'`.

# %% [raw]
# # BEGIN QUESTION
# name: q2_1

# %% [raw]
# # BEGIN SOLUTION

# %%
def k_nearest_songs(new_song, labeled_songs, k):
    """Return the k numerical feature rows closest to new_song."""
    # BEGIN SOLUTION
    with_distances = labeled_songs.copy()
    with_distances['distance'] = distances_to_song(new_song, labeled_songs)
    return with_distances.nsmallest(k, 'distance')
    # END SOLUTION

k_nearest_songs(test_features.iloc[0], training_features, 5)
# Out:
#       danceability  energy  speechiness  acousticness  instrumentalness  \
# 1013         0.705   0.852        0.252         0.226          0.000626
# 1502         0.607   0.843        0.218         0.103          0.000044
# 1671         0.690   0.745        0.205         0.167          0.000000
# 1536         0.695   0.727        0.181         0.221          0.000000
# 956          0.734   0.805        0.247         0.246          0.000000
#
#       liveness  valence  distance
# 1013    0.1400    0.671  0.144272
# 1502    0.1070    0.582  0.145334
# 1671    0.1840    0.666  0.172873
# 1536    0.0911    0.616  0.174747
# 956     0.1080    0.710  0.178656

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
small_songs = pd.DataFrame([[0.0, 0.0], [0.4, 0.4], [0.8, 0.8]], columns=['a', 'b'], index=['a', 'b', 'c'])
new_song = pd.Series([0.3, 0.3], index=['a', 'b'])
answer = k_nearest_songs(new_song, small_songs, 2)
bool(isinstance(answer, pd.DataFrame) and answer.shape[0] == 2 and 'distance' in answer.columns and answer.index.tolist() == ['b', 'a'] and answer['distance'].is_monotonic_increasing)
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# **Question 2.2.** Define `neighbor_votes(new_song, labeled_songs, labels, k)`. `labeled_songs` contains only numerical features and `labels` contains the corresponding genres. Return a Series whose index contains the genres represented among the `k` nearest songs and whose values are their vote counts.

# %% [raw]
# # BEGIN QUESTION
# name: q2_2

# %% [raw]
# # BEGIN SOLUTION

# %%
def neighbor_votes(new_song, labeled_songs, labels, k):
    """Count the label votes among the k nearest feature rows."""
    # BEGIN SOLUTION
    neighbors = k_nearest_songs(new_song, labeled_songs, k)
    return labels.loc[neighbors.index].value_counts()
    # END SOLUTION

neighbor_votes(test_features.iloc[0], training_features, training_labels, 5)
# Out:
# genre
# hip-hop    5
# Name: count, dtype: int64

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
small_songs = pd.DataFrame([[0.0, 0.0], [0.1, 0.1], [0.2, 0.2], [0.9, 0.9]], columns=['a', 'b'])
labels = pd.Series(['rock', 'rock', 'classical', 'hip-hop'])
new_song = pd.Series([0.05, 0.05], index=['a', 'b'])
votes = neighbor_votes(new_song, small_songs, labels, 3)
bool(isinstance(votes, pd.Series) and votes.sum() == 3 and votes.to_dict() == {'rock': 2, 'classical': 1})
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# **Question 2.3.** Define `predict_knn(new_song, labeled_songs, labels, k)`. It should return the genre with the most votes among the `k` nearest songs. If two or more genres are tied for the most votes, return the alphabetically first tied genre. For example, a tie between `'hip-hop'` and `'rock'` should return `'hip-hop'`.

# %% [raw]
# # BEGIN QUESTION
# name: q2_3

# %% [raw]
# # BEGIN SOLUTION

# %%
def predict_knn(new_song, labeled_songs, labels, k):
    """Predict a genre using a majority vote among k nearest feature rows."""
    # BEGIN SOLUTION
    votes = neighbor_votes(new_song, labeled_songs, labels, k)
    return votes.sort_index().idxmax()
    # END SOLUTION

predict_knn(test_features.iloc[0], training_features, training_labels, 5)
# Out:
# 'hip-hop'

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
small_songs = pd.DataFrame([[0.0, 0.0], [0.1, 0.1], [0.2, 0.2], [0.9, 0.9], [0.8, 0.8]], columns=['a', 'b'])
labels = pd.Series(['rock', 'rock', 'classical', 'hip-hop', 'hip-hop'])
new_song = pd.Series([0.05, 0.05], index=['a', 'b'])
bool(predict_knn(new_song, small_songs, labels, 3) == 'rock')
# Out:
# True

# %%
tie_songs = pd.DataFrame([[0.0, 0.0], [0.1, 0.1], [0.2, 0.2], [0.3, 0.3]], columns=['a', 'b'])
labels = pd.Series(['rock', 'hip-hop', 'rock', 'hip-hop'])
new_song = pd.Series([0.05, 0.05], index=['a', 'b'])
bool(predict_knn(new_song, tie_songs, labels, 4) == 'hip-hop')
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# **Question 2.4.** Use `predict_knn` with `k=5` to predict every test song. Store the predictions in `five_nn_predictions`. Then create `five_nn_results`, with the same three columns as `one_nn_results`, and assign its proportion of correct predictions to `five_nn_accuracy`.

# %% [raw]
# # BEGIN QUESTION
# name: q2_4

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION
five_nn_predictions = test_features.apply(
    lambda song: predict_knn(song, training_features, training_labels, 5), axis=1
)
five_nn_results = pd.DataFrame({
    'genre': test_labels,
    'predicted_genre': five_nn_predictions
})
five_nn_results = five_nn_results.assign(
    correct=five_nn_results['genre'] == five_nn_results['predicted_genre']
)
five_nn_accuracy = five_nn_results['correct'].mean()
# END SOLUTION
five_nn_accuracy
# Out:
# np.float64(0.8678571428571429)

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
bool(isinstance(five_nn_predictions, pd.Series) and five_nn_predictions.index.equals(test_songs.index))
# Out:
# True

# %%
bool(isinstance(five_nn_results, pd.DataFrame) and set(five_nn_results.columns) == {'genre', 'predicted_genre', 'correct'})
# Out:
# True

# %%
bool(np.isclose(five_nn_accuracy, five_nn_results['correct'].mean()))
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# **Question 2.5.** Compare the two held-out accuracies. Store `'1-NN'` in `better_model` if `one_nn_accuracy` is larger, `'5-NN'` if `five_nn_accuracy` is larger, and `'tie'` if they are equal.
#
# Then, in the Markdown cell below, explain why 1-NN can be sensitive to an unusual training song.

# %% [raw]
# # BEGIN QUESTION
# name: q2_5

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION
if one_nn_accuracy > five_nn_accuracy:
    better_model = '1-NN'
elif five_nn_accuracy > one_nn_accuracy:
    better_model = '5-NN'
else:
    better_model = 'tie'
better_model
# END SOLUTION
# Out:
# '5-NN'

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
bool(better_model in {'1-NN', '5-NN', 'tie'})
# Out:
# True

# %%
bool((better_model == '1-NN' and one_nn_accuracy > five_nn_accuracy) or (better_model == '5-NN' and five_nn_accuracy > one_nn_accuracy) or (better_model == 'tie' and np.isclose(one_nn_accuracy, five_nn_accuracy)))
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# *Your response here.*

# %% [markdown]
# **Question 2.6.** Compare several choices of $k$. Create a DataFrame called `accuracy_by_k`, indexed by the values `1`, `3`, `5`, and `9`, with one column named `'accuracy'`. Each value should be the test accuracy produced by `predict_knn` for that value of $k$. Then make a line plot of the accuracies. The plot is not graded.
#
# You may define a helper function if it makes your solution easier to read.

# %% [raw]
# # BEGIN QUESTION
# name: q2_6

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION
def accuracy_for_k(k):
    predictions = test_features.apply(
        lambda song: predict_knn(song, training_features, training_labels, k), axis=1
    )
    return (predictions == test_labels).mean()

accuracy_by_k = pd.DataFrame({'k': [1, 3, 5, 9]})
accuracy_by_k = accuracy_by_k.assign(accuracy=accuracy_by_k['k'].apply(accuracy_for_k)).set_index('k')
accuracy_by_k.plot(kind='line', marker='o', ylabel='test accuracy');
# END SOLUTION

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
bool(isinstance(accuracy_by_k, pd.DataFrame) and accuracy_by_k.index.tolist() == [1, 3, 5, 9])
# Out:
# True

# %%
bool(accuracy_by_k.columns.tolist() == ['accuracy'])
# Out:
# True

# %%
bool(((accuracy_by_k['accuracy'] >= 0) & (accuracy_by_k['accuracy'] <= 1)).all())
# Out:
# True

# %%
bool(np.isclose(accuracy_by_k.loc[5, 'accuracy'], five_nn_accuracy))
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# **Question 2.7.** Assign `best_k` to the value of $k$ in `accuracy_by_k` with the largest test accuracy. If there is a tie, choose the smaller value of $k$.

# %% [raw]
# # BEGIN QUESTION
# name: q2_7

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION
best_k = accuracy_by_k['accuracy'].idxmax()
best_k
# END SOLUTION
# Out:
# np.int64(9)

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
bool(best_k in {1, 3, 5, 9})
# Out:
# True

# %%
bool(np.isclose(accuracy_by_k.loc[best_k, 'accuracy'], accuracy_by_k['accuracy'].max()))
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# **Question 2.8.** Which genre is hardest for 5-NN to classify? Create `five_nn_by_genre`, indexed by genre, with one column named `'accuracy'` containing the proportion of correct 5-NN predictions for each actual genre. Then assign `hardest_genre` to the genre with the lowest accuracy.

# %% [raw]
# # BEGIN QUESTION
# name: q2_8

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION
five_nn_by_genre = five_nn_results.groupby('genre')['correct'].mean().to_frame('accuracy')
hardest_genre = five_nn_by_genre['accuracy'].idxmin()
five_nn_by_genre
# END SOLUTION
# Out:
#            accuracy
# genre
# classical  0.905556
# hip-hop    0.871795
# rock       0.827027

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
bool(isinstance(five_nn_by_genre, pd.DataFrame) and five_nn_by_genre.columns.tolist() == ['accuracy'])
# Out:
# True

# %%
bool(five_nn_by_genre.index.tolist() == ['classical', 'hip-hop', 'rock'])
# Out:
# True

# %%
bool(hardest_genre in five_nn_by_genre.index and np.isclose(five_nn_by_genre.loc[hardest_genre, 'accuracy'], five_nn_by_genre['accuracy'].min()))
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# ## Finish Line 🏁
#
# You built 1-NN and k-NN classifiers from scratch. In both cases, the classifier uses labeled examples, so this is **supervised learning**. Using several neighbors can make a classifier less sensitive to any one training song, but a very large value of $k$ can ignore useful local patterns.

# %%
# For your convenience, you can run this cell to run all the tests at once!
grader.check_all()
